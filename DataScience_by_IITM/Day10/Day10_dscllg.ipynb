# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r"C:\Users\Dell\OneDrive\Desktop\pandajpimage.jpg")
arr
# Out:
# array([[[115, 147,  48],
#         [ 90, 121,  28],
#         [ 66,  96,  10],
#         ...,
#         [173, 191, 201],
#         [186, 206, 207],
#         [111, 132, 125]],
#
#        [[108, 140,  41],
#         [ 85, 116,  23],
#         [ 62,  92,   6],
#         ...,
#         [160, 179, 186],
#         [177, 197, 196],
#         [108, 130, 118]],
#
#        [[102, 134,  35],
#         [ 79, 110,  17],
#         [ 59,  89,   3],
#         ...,
#         [169, 189, 190],
#         [184, 205, 198],
#         [114, 137, 121]],
#
#        ...,
#
#        [[168, 188,  91],
#         [198, 218, 121],
#         [142, 164,  63],
#         ...,
#         [ 79, 119,   0],
#         [ 82, 122,   0],
#         [ 94, 133,   8]],
#
#        [[119, 139,  42],
#         [149, 169,  70],
#         [108, 130,  29],
#         ...,
#         [ 72, 112,   0],
#         [ 77, 117,   0],
#         [ 92, 130,   8]],
#
#        [[ 91, 111,  14],
#         [116, 136,  37],
#         [ 86, 108,   7],
#         ...,
#         [ 68, 108,   0],
#         [ 73, 113,   0],
#         [ 87, 125,   4]]], dtype=uint8)

# %%
panda_arr = arr.copy()

# %%
plt.imshow(panda_arr)

# %%
panda_arr.shape
# Out:
# (148, 268, 3)

# %%
a = np.random.randint(1,50,(3,3,3))
plt.imshow(a)

# %%
a = np.random.randint(0,255,(3,3,3))
plt.imshow(a)

# %%
a = np.random.randint(0,255,(5,5,3))
plt.imshow(a)

# %%
a = np.random.randint(0,255,(500,500,3))
plt.imshow(a)

# %%
while True:
    import numpy as np
    import time 
    import matplotlib.pyplot as plt
    a = np.random.randint(0,255,(5,5,3))
    plt.imshow(a)
    plt.show()
    time.sleep(0.3)
    display(clear = True)

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[218, 239, 216],
#         [208,   1, 231],
#         [140,  73,  52],
#         [ 36, 171,  32]],
#
#        [[167,  64,  17],
#         [ 27, 197,  33],
#         [204,   8,  25],
#         [124, 123, 161]],
#
#        [[190,  68,  36],
#         [168, 210, 109],
#         [174, 140,  54],
#         [101,  15, 240]],
#
#        [[112, 195, 204],
#         [ 82, 212,  97],
#         [168, 158, 212],
#         [205, 162, 198]]])

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(a[0])

# %%
plt.imshow(final_arr[1])

# %%
plt.imshow(final_arr[0])

# %%
arr_1 = np.split(a,2,axis = 1)

# %%
len(arr_1)
# Out:
# 2

# %%
arr_3_part = np.split(a,3,axis = 2)
arr_3_part
# Out:
# [array([[[218],
#          [208],
#          [140],
#          [ 36]],
#
#         [[167],
#          [ 27],
#          [204],
#          [124]],
#
#         [[190],
#          [168],
#          [174],
#          [101]],
#
#         [[112],
#          [ 82],
#          [168],
#          [205]]]),
#  array([[[239],
#          [  1],
#          [ 73],
#          [171]],
#
#         [[ 64],
#          [197],
#          [  8],
#          [123]],
#
#         [[ 68],
#          [210],
#          [140],
#          [ 15]],
#
#         [[195],
#          [212],
#          [158],
#          [162]]]),
#  array([[[216],
#          [231],
#          [ 52],
#          [ 32]],
#
#         [[ 17],
#          [ 33],
#          [ 25],
#          [161]],
#
#         [[ 36],
#          [109],
#          [ 54],
#          [240]],
#
#         [[204],
#          [ 97],
#          [212],
#          [198]]])]

# %%
len(arr_3_part)
# Out:
# 3

# %%
arr_3_part[0]
# Out:
# array([[[218],
#         [208],
#         [140],
#         [ 36]],
#
#        [[167],
#         [ 27],
#         [204],
#         [124]],
#
#        [[190],
#         [168],
#         [174],
#         [101]],
#
#        [[112],
#         [ 82],
#         [168],
#         [205]]])

# %%
plt.imshow(arr_3_part[0])

# %%
plt.imshow(np.split(arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(arr,2,axis = 0)[0])

# %%
plt.imshow(np.split(arr,4,axis = 1)[0])

# %%
arr.shape
# Out:
# (148, 268, 3)

# %%
268//3
# Out:
# 89

# %%
plt.imshow(arr[: , :89,:])

# %%
plt.imshow(arr[: , 89:89*2,:])

# %%
plt.imshow(arr[: , 89*2:89*3,:])

# %%
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[229,  80, 491, 256],
#        [227,  48, 429, 482],
#        [262, 391, 343,  66],
#        [217, 238, 188, 178]])

# %%
np.where(a>200)
# Out:
# (array([0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3], dtype=int64),
#  array([0, 2, 3, 0, 2, 3, 0, 1, 2, 0, 1], dtype=int64))

# %%
np.where(a>200,'high sales' , a)
# Out:
# array([['high sales', '80', 'high sales', 'high sales'],
#        ['high sales', '48', 'high sales', 'high sales'],
#        ['high sales', 'high sales', 'high sales', '66'],
#        ['high sales', 'high sales', '188', '178']], dtype='<U11')

# %%
np.clip(a,100,250 ) #it filled the values lower than 100 with 100  and filled the values with the value more than 250 with 250 and the rest of the data is the same
#it used to remove the outliers
# Out:
# array([[229, 100, 250, 250],
#        [227, 100, 250, 250],
#        [250, 250, 250, 100],
#        [217, 238, 188, 178]])

# %%
#Broadcasting

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,2))

print(a)
print('=================== \n \n')
print(b)
# Out:
# [9 4 6 5 4 3 8]
# ===================
#
#
# [[3 1]
#  [4 4]]

# %%
a + b
# Out:
# array([[12, 11,  9,  9, 11, 14,  5],
#        [ 9, 11,  8,  9,  7, 15, 13]])

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,2))

print(a)
print('=================== \n \n')
print(b)
# Out:
# [2 3 7 2 6 4 6]
# ===================
#
#
# [[4 7]
#  [9 5]]

# %% [markdown]
# # Introduction to pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %%
import random

products = ['Chair','Tables','Laptop','Mobile phones','Charger']
region = ['East','West','North','South']
all_date = pd.date_range('01/01/2025','23/07/2025')

data = {'Order Id' : range(1,1001) ,
        'Region Name' : random.choices(region,k = 1000),
       'Product name' : random.choices(products,k = 1000),
       'Sales' : np.random.randint(100,10000,1000),
       'Qty' : np.random.randint(1,10,1000),
       'Profit' : np.random.randint(-10000,10000,1000),
       'Date Column' : random.choices(all_date,k=1000)}

table = pd.DataFrame(data)
table
# Out:
#      Order Id Region Name   Product name  Sales  Qty  Profit Date Column
# 0           1       South  Mobile phones   1038    6   -4892  2025-02-22
# 1           2        West          Chair   6482    2    1789  2025-01-03
# 2           3        East  Mobile phones   9735    6    6059  2025-07-02
# 3           4        West  Mobile phones    252    8   -9062  2025-01-08
# 4           5        West          Chair   1952    8    2220  2025-02-19
# ..        ...         ...            ...    ...  ...     ...         ...
# 995       996       South          Chair    836    2     141  2025-03-09
# 996       997        West  Mobile phones   1971    8    3168  2025-03-01
# 997       998       South        Charger   2074    5   -7696  2025-04-19
# 998       999       South         Tables   5673    5    4128  2025-03-04
# 999      1000       South        Charger   8456    7    4021  2025-01-21
#
# [1000 rows x 7 columns]

# %%
table.head(10)
# Out:
#    Order Id Region Name   Product name  Sales  Qty  Profit Date Column
# 0         1       South  Mobile phones   1038    6   -4892  2025-02-22
# 1         2        West          Chair   6482    2    1789  2025-01-03
# 2         3        East  Mobile phones   9735    6    6059  2025-07-02
# 3         4        West  Mobile phones    252    8   -9062  2025-01-08
# 4         5        West          Chair   1952    8    2220  2025-02-19
# 5         6       South  Mobile phones   2569    4   -2195  2025-01-28
# 6         7       North          Chair   8234    6   -5119  2025-06-17
# 7         8       North          Chair   8165    3   -9614  2025-05-21
# 8         9        East  Mobile phones   1803    4   -8836  2025-07-23
# 9        10        West         Laptop    290    9    6423  2025-01-11

# %%
table.tail(7)
# Out:
#      Order Id Region Name   Product name  Sales  Qty  Profit Date Column
# 993       994       North        Charger   9901    4     947  2025-05-17
# 994       995       North          Chair   9053    7    2249  2025-02-07
# 995       996       South          Chair    836    2     141  2025-03-09
# 996       997        West  Mobile phones   1971    8    3168  2025-03-01
# 997       998       South        Charger   2074    5   -7696  2025-04-19
# 998       999       South         Tables   5673    5    4128  2025-03-04
# 999      1000       South        Charger   8456    7    4021  2025-01-21

# %%
table.sample(5)
# Out:
#      Order Id Region Name   Product name  Sales  Qty  Profit Date Column
# 258       259       North          Chair   4967    6    7333  2025-03-31
# 447       448        East         Tables   6469    9    -470  2025-01-20
# 427       428       North          Chair   9390    9   -9706  2025-03-19
# 430       431       South  Mobile phones   9982    4   -2470  2025-03-16
# 757       758        East        Charger   3517    8   -7881  2025-02-15

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Id      1000 non-null   int64
#  1   Region Name   1000 non-null   object
#  2   Product name  1000 non-null   object
#  3   Sales         1000 non-null   int32
#  4   Qty           1000 non-null   int32
#  5   Profit        1000 non-null   int32
#  6   Date Column   1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
table.columns
# Out:
# Index(['Order Id', 'Region Name', 'Product name', 'Sales', 'Qty', 'Profit',
#        'Date Column'],
#       dtype='object')

# %%
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#isna is a function that shows the null value in the table

# %%
table.isna()
# Out:
#      Order Id  Region Name  Product name  Sales    Qty  Profit  Date Column
# 0       False        False         False  False  False   False        False
# 1       False        False         False  False  False   False        False
# 2       False        False         False  False  False   False        False
# 3       False        False         False  False  False   False        False
# 4       False        False         False  False  False   False        False
# ..        ...          ...           ...    ...    ...     ...          ...
# 995     False        False         False  False  False   False        False
# 996     False        False         False  False  False   False        False
# 997     False        False         False  False  False   False        False
# 998     False        False         False  False  False   False        False
# 999     False        False         False  False  False   False        False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# Order Id  Region Name  Product name  Sales  Qty    Profit  Date Column
# False     False        False         False  False  False   False          1000
# Name: count, dtype: int64

# %%
table.isnull
# Out:
# <bound method DataFrame.isnull of      Order Id Region Name   Product name  Sales  Qty  Profit Date Column
# 0           1       South  Mobile phones   1038    6   -4892  2025-02-22
# 1           2        West          Chair   6482    2    1789  2025-01-03
# 2           3        East  Mobile phones   9735    6    6059  2025-07-02
# 3           4        West  Mobile phones    252    8   -9062  2025-01-08
# 4           5        West          Chair   1952    8    2220  2025-02-19
# ..        ...         ...            ...    ...  ...     ...         ...
# 995       996       South          Chair    836    2     141  2025-03-09
# 996       997        West  Mobile phones   1971    8    3168  2025-03-01
# 997       998       South        Charger   2074    5   -7696  2025-04-19
# 998       999       South         Tables   5673    5    4128  2025-03-04
# 999      1000       South        Charger   8456    7    4021  2025-01-21
#
# [1000 rows x 7 columns]>
