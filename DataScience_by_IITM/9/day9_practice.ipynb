# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r"C:\Users\Dell\OneDrive\Desktop\pandajpimage.jpg")
print('done')
# Out:
# done

# %%
plt.imshow(arr)

# %%
arr.shape
# Out:
# (148, 268, 3)

# %%
plt.imshow(arr[:,:,0])

# %%
plt.imshow(arr[:,:,1])

# %%
plt.imshow(arr[:,:,2])

# %%
arr_copy = arr.copy()
arr_copy[:,:,0] = 0 #:, :, 0] = 0 removes the red completly
plt.imshow(arr_copy)

# %%
arr_copy = arr.copy()
arr_copy[:,:,1] = 0 #:, :, 0] = 0 removes the green completly
plt.imshow(arr_copy)

# %%
arr_copy = arr.copy()
arr_copy[:,:,2] = 0 #:, :, 0] = 0 removes the green completly
plt.imshow(arr_copy)

# %%
750*4
# Out:
# 3000

# %%
arr.shape
# Out:
# (148, 268, 3)

# %%
plt.imshow(arr[23:50,100:165,:])

# %%
plt.imshow(np.concatenate([arr,arr],axis = 1))

# %%
x = 5
final_arr = np.concatenate([arr]*x,axis = 1)
np.concatenate([final*])
